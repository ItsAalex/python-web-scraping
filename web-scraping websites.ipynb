# %% [markdown]
# # WEB SCRAPING WITHOUT AUTOMATIZATION

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

base_url = "https://www.paginebianche.it/"
page = 1
persons = []
print("Please insert the surname that you want to search")
surname = input("").lower().strip()
while True:
    raw_html_url = f"https://www.paginebianche.it/persone?qs={surname}&p={page}"
    
    # Fetch the HTML content
    raw_html = requests.get(raw_html_url)
    html_content = raw_html.text
    
    # Parse the HTML
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Extract the listings on the current page
    listings = soup.find_all('div', class_="list-element__content")
    

    
    # Iterate over each listing
    for listing in listings:
        # Extract the name, address, and telephone
        name_element = listing.find('h2', class_="list-element__title ln-3 org fn")
        name = name_element.text.strip() if name_element else "N/A"
    
        address_element = listing.find('div', class_="list-element__address adr")
        address = address_element.text.strip() if address_element else "N/A"
    
        telephone_element = listing.find('div', class_="btn__label tel")
        telephone = telephone_element.text.strip() if telephone_element else "N/A"
    
        # Create the person list
        person = [name, address, telephone]
    
        # Append the person list to the persons list
        persons.append(person)
    
    # Increment the page number
    page += 1
        # If no listings found, exit the loop
    if not listings:
        break
# Print the persons list
for person in persons:
    print(person)
# Out:
# Please insert the surname that you want to search
# petrovic
# ['Petrovic Ambra', "Via Martiri Della Liberta' 50 - 34079 Staranzano (GO)", '0481 778129']
# ['Petrovic Danijela', 'Via Padovan Giglio 5 - 34138 Trieste (TS)', '040 2034217']
# ['Petrovic Dejan', 'Via Roma 9 - 38054 Tonadico (TN)', '388 6562947']
# ['Petrovic Dino', 'Via Protomartiri Francescani 77 - 06081 Assisi (PG)', '075 8040739']
# ['Petrovic Dragana', 'Via Campo Marte 9 - 25128 Brescia (BS)', '030 3700037']
# ['Petrovic Dragica', 'Via Mantegazza Paolo 37 - 19126 La spezia (SP)', '0187 523591']
# ['Petrovic Drasko', 'Via Aldo Moro 11 - 29027 Podenzano (PC)', '0523 554203']
# ['Petrovic Dubravka', 'Via Della Palazzina 32 - 25124 Brescia (BS)', '030 3534161']
# ['Petrovic Dusko', 'Via S. Vito 18 - 36034 Malo (VI)', '0445 605498']
# ['Petrovic Erzebet', 'Via Non Dichiarato 00 - 37063 Isola della scala (VR)', '327 3146778']
# ['Petrovic Gordana', 'Via Isonzo 58/C - 22100 Como (CO)', '031 526172']
# ['Petrovic Ljubomir', 'Via Udine 46 - 33054 Lignano sabbiadoro (UD)', '0431 70078']
# ['Petrovic Milenko', 'Via Trieste 10/A - 35010 Carmignano di brenta (PD)', '049 9430034']
# ['Petrovic Mirjana', 'Via Michelangelo Buonarroti 1/12 - 33072 Casarsa della delizia (PN)', '0434 871168']
# ['Petrovic Mirko', 'Via Casetta 128 - 37040 Veronella (VR)', '0442 47601']
# ['Petrovic Nadezda', "Via Martiri Della Liberta' 2/A - 35016 Piazzola sul brenta (PD)", '049 5599440']
# ['Petrovic Nikola', 'Via Del Riso 9/F - 27010 Cura carpignano (PV)', '0382 491779']
# ['Petrovic Silvana', 'Via Commerciale 161 - 34134 Trieste (TS)', '040 422734']
# ['Petrovic Snezana', 'Via Micca Pietro 21/2 - 40033 Casalecchio di reno (BO)', '051 591572']
# ['Petrovic Vera', 'Via Conte Di Carmagnola 32 - 00176 Roma (RM)', '349 1446257']
# ['Petrovic Vesna', 'Via Minzoni Don Giovanni 18 - 15121 Alessandria (AL)', '0131 346434']
# ['Petrovic Zivana', 'Via Ponziana 6 - 34137 Trieste (TS)', '040 662786']
# ['Petrovic Zlatibor', "Via Dell' Istria 114 - 34137 Trieste (TS)", '040 2604081']
# ['Petrovic Zorica', 'Via Bortolamasi 59 - 41012 Carpi (MO)', '059 5800949']
# ["Petrovic' Gordana", 'Via Saretta Monsignor Luigi 17/2 - 30027 San dona di piave (VE)', '0421 565055']
# ['Suprina Petrovic Igor', 'Viale Virgilio 5 - 80123 Napoli (NA)', '081 7690553']

# %% [markdown]
# # WEBSCRAPING WITH AUTOMATIZATION

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import json
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
i = 0
browser = webdriver.Chrome()
print("Please insert the surname that you want to search")
surname = input("").lower().strip()
browser.get(f'https://tel.search.ch/?was={surname}&privat=1&pages=1')

items = []
last_height = browser.execute_script("return document.body.scrollHeight")
while True:
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    elements = browser.find_elements(By.CSS_SELECTOR, "body > div")
    textElements = []
    
# Get the final URL
final_url = browser.current_url

# Close the browser
browser.quit()



base_url = "https://www.search.ch/"
# Fetch the HTML content
raw_html = requests.get(final_url)
html_content = raw_html.text
# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')
# Create an empty list to store persons
persons = []
# Extract the listings on the current page
listings = soup.find_all('table', class_='tel-resultentry')
# Iterate over each listing
for listing in listings:
    # Extract the name, address, and telephone
    name_element = listing.find('h1')
    name = name_element.text.strip()
    address_element = listing.find('div', class_='tel-address')
    address = address_element.text.strip()
    telephone_element = listing.find('a', class_='tel-result-action')
    if telephone_element:
        telephone_href = telephone_element.get('href')
        telephone_match = re.search(r'\+(\d+)', telephone_href)
        if telephone_match:
            telephone = telephone_match.group(1)
        else:
            telephone = 'N/A'
    else:
        telephone = 'N/A'
    # Create the person list
    person = [name, address, telephone]
    # Append the person list to the persons list
    persons.append(person)
# Print the persons list
for person in persons:
    i+=1
    print(i,person)
# Out:
# Please insert the surname that you want to search
# cvetkovic
# 1 ['Bariska Cvetkovic, Denise', 'Haldenweg 4, 5235 Rüfenach AG', '41447261203']
# 2 ['Cvetkovic, Bane und Dusica', 'Rüttistrasse 8, 6467 Schattdorf UR', '41418710239']
# 3 ['Cvetkovic, Bratislav (-Jankovic)', 'Florahof 2, 8353 Elgg ZH', '41523643416']
# 4 ['Cvetkovic, Bratislav', 'Zürcherstrasse 30, 8102 Oberengstringen ZH', '41447511792']
# 5 ['Cvetkovic, Cedomir', 'Via Ernesto Bosia 15, 6900 Paradiso TI', '41919800903']
# 6 ['Cvetkovic, Danijela', 'Austrasse, 9230 Flawil SG', '41767099791']
# 7 ['Cvetkovic, Dragan', 'Obere Fischbachstrasse 5, 8932 Mettmenstetten ZH', '41447682338']
# 8 ['Cvetkovic, Dragan', 'Rainstrasse 13, 9500 Wil SG', '41719254358']
# 9 ['Cvetkovic, Goran', 'Austrasse 3, 9230 Flawil SG', '41713931231']
# 10 ['Cvetkovic, Ivana und Dejan', 'Ruopigenplatz 24, 6015 Luzern', '41412407175']
# 11 ['Cvetkovic, Jadranca', 'Rue des Minoteries 5, 1205 Genève', '41223415220']
# 12 ['Cvetkovic, Ljiljana (-Stankovic)', 'Weiherstrasse 20, 8307 Effretikon ZH', '41523431184']
# 13 ['Cvetkovic, Ljubisav', 'Chemin des Chesaux 2A, 1053 Cugy VD', '41794473458']
# 14 ['Cvetkovic Markovic, Gordana', 'Chäppelimatte 1, 6210 Sursee LU', '41413405602']
# 15 ['Cvetkovic, Mejrema', 'Rüeggisingerstrasse 91, 6032 Emmen LU', '41412811518']
# 16 ['Cvetkovic, Milan', 'Hörnlistrasse 4, 8153 Rümlang ZH', '41443030874']
# 17 ['Cvetkovic, Miodrag', 'Bruggwaldstrasse 92, 9300 Wittenbach SG', '41712983150']
# 18 ['Cvetkovic, Mira', 'Krauerstrasse 5, 6020 Emmenbrücke LU', '41412602868']
# 19 ['Cvetkovic, Nasa', 'Bogenstrasse 7, 9400 Rorschach SG', '41789259228']
# 20 ['Cvetkovic, Nikola', 'Riffigring 2, 6020 Emmenbrücke LU', '41412807685']
# 21 ['Cvetkovic, Nikola', 'Warteggweg 22, 9403 Goldach SG', '41718453148']
# 22 ['Cvetkovic, Radenko (-Djokic)', 'Spelterinistrasse 19, 9602 Bazenheid SG', '41719314665']
# 23 ['Cvetkovic, Ranko', 'Sagenmattstrasse 11, 6003 Luzern', '41412400056']
# 24 ['Cvetkovic, Ratko', 'August-Cuenistrasse 19, 4222 Zwingen BL', '41617611258']
# 25 ['Cvetkovic, Sandra', 'Ruopigenring 83, 6015 Luzern', '41412807638']
# 26 ['Cvetkovic, Sasa', 'Listrighalde 7, 6020 Emmenbrücke LU', '41412800911']
# 27 ['Cvetkovic, Slavisa', 'Via Geretta 19, 6900 Paradiso TI', '41919943581']
# 28 ['Cvetkovic, Snezana (-Mihajlova)', 'Spitalstrasse 9, 8630 Rüti ZH', '41552412337']
# 29 ['Cvetkovic, Stojan', 'Nordstrasse 8, 9532 Rickenbach b. Wil TG', '41719231041']
# 30 ['Cvetkovic, Tanja', 'Innerfeldstrasse 3, 4528 Zuchwil SO', '41326852267']
# 31 ['Cvetkovic, Vladimir', "Rue de l'Hôpital 31B, 1400 Yverdon-les-Bains VD", '41245553373']
# 32 ['Cvetkovic, Zelimir', 'Rütlistrasse 17, 8307 Effretikon ZH', '41523437052']
# 33 ['Cvetkovic, Zivan', 'Hauptstrasse 93, 8224 Löhningen SH', '41787426049']
# 34 ['Cvetkovic, Zivan', 'Luggwegstrasse 50, 8048 Zürich', '41444312360']
# 35 ['Cvetkovic, Zivorad', 'Ruelle du Betty 14, 1937 Orsières VS', '41277832188']
# 36 ['Cvetkovic, Zoran', 'Zürcherstrasse 27, 5400 Baden AG', '41562091910']
# 37 ['Pesic Cvetkovic, Zaklina', 'Wynenfeldweg 38, 5033 Buchs AG', '41628226245']
# 38 ['Djoric, Roska (-Cvetkovic)', 'Hohlstrasse 347, 8004 Zürich', '41433218253']
# 39 ['Guerra, Walter (-Cvetkovic)', 'Via Mondacce 4, 6648 Minusio TI', '41917446716']
# 40 ['Jannotta, Daniel und Marina (-Cvetkovic)', 'Bankstrasse 20, 5432 Neuenhof AG', '41564061228']
# 41 ['Jovanovic, Dragan (-Cvetkovic)', 'Südallee 16a, 5034 Suhr AG', '41628232372']
# 42 ['Stojanovic, Marina (-Cvetkovic)', 'Ruopigenhöhe 22, 6015 Luzern', '41412606747']
# 43 ['Zivkovic, Miliza (-Cvetkovic)', 'Chamerstrasse 79, 6300 Zug', '41417110993']

# %% [markdown]
# # FOOTBALL CLUB INFO

# %%
import requests
import pandas as pd

headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"e90558a479"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

# Make the request to get the shotmap data from the API
response_api = requests.get('https://api.sofascore.com/api/v1/event/11605972/shotmap', headers=headers)

# Check the status code of the API request
if response_api.status_code == 200:
    # Convert JSON data to a DataFrame
    shots_data = response_api.json()['shotmap']
    df = pd.json_normalize(shots_data)

    # First parameter is the location where we want to store our shots_data.csv
    df.to_csv('/home/ali-g/python/shots_data.csv', index=False)

    print("Data saved to CSV file.")
else:
    print(f"Error in the API request: {response_api.status_code}")
# Out:
# Data saved to CSV file.
